# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Köppen classification labels and colors
koppen_labels = {
    11: 'Af', 12: 'Am', 13: 'As', 14: 'Aw',
    21: 'BWk', 22: 'BWh', 26: 'BSk', 27: 'BSh',
    31: 'Cfa', 32: 'Cfb', 33: 'Cfc', 34: 'Csa',
    35: 'Csb', 36: 'Csc', 37: 'Cwa', 38: 'Cwb',
    39: 'Cwc', 41: 'Dfa', 42: 'Dfb', 43: 'Dfc',
    44: 'Dfd', 45: 'Dsa', 46: 'Dsb', 47: 'Dsc',
    48: 'Dsd', 49: 'Dwa', 50: 'Dwb', 51: 'Dwc',
    52: 'Dwd', 61: 'EF', 62: 'ET'
}

koppen_color_map = {
    11: '#1a9850', 12: '#66bd63', 13: '#a6d96a', 14: '#d9ef8b',
    21: '#fee08b', 22: '#fdae61', 26: '#f46d43', 27: '#d73027',
    31: '#762a83', 32: '#9970ab', 33: '#c2a5cf', 34: '#e7d4e8',
    35: '#f7f7f7', 36: '#d9f0d3', 37: '#a6dba0', 38: '#5aae61',
    39: '#00441b', 41: '#006d2c', 42: '#238b45', 43: '#41ab5d',
    44: '#74c476', 45: '#a1d99b', 46: '#c7e9c0', 47: '#e5f5e0',
    48: '#fd8d3c', 49: '#fdae6b', 50: '#fdd0a2', 51: '#fee6ce',
    52: '#e31a1c', 61: '#fb6a4a', 62: '#fc9272'
}

# Create a list of patches for the legend
legend_elements = [Patch(facecolor=koppen_color_map[key], edgecolor='black', label=f"{koppen_labels[key]} ({key})") for key in koppen_labels]

# Create the figure and legend
fig, ax = plt.subplots(figsize=(4, 8))  # Adjust the size to fit the number of legend items
ax.axis('off')  # Hide axes

# Add the legend to the figure
legend = ax.legend(handles=legend_elements, title="Köppen-Geiger Climate Classification", loc='center', frameon=True)

# Save the legend as an image (PNG)
plt.savefig("Koppen_Classification_Legend.png", bbox_inches='tight', dpi=300)

# Show the plot (optional)
plt.show()

print("Legend image created and saved as 'Koppen_Classification_Legend.png'")
# Out:
# Legend image created and saved as 'Koppen_Classification_Legend.png'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Köppen classification labels and colors
koppen_labels = {
    11: 'Af', 12: 'Am', 13: 'As', 14: 'Aw',
    21: 'BWk', 22: 'BWh', 26: 'BSk', 27: 'BSh',
    31: 'Cfa', 32: 'Cfb', 33: 'Cfc', 34: 'Csa',
    35: 'Csb', 36: 'Csc', 37: 'Cwa', 38: 'Cwb',
    39: 'Cwc', 41: 'Dfa', 42: 'Dfb', 43: 'Dfc',
    44: 'Dfd', 45: 'Dsa', 46: 'Dsb', 47: 'Dsc',
    48: 'Dsd', 49: 'Dwa', 50: 'Dwb', 51: 'Dwc',
    52: 'Dwd', 61: 'EF', 62: 'ET'
}

koppen_color_map = {
    11: '#1a9850', 12: '#66bd63', 13: '#a6d96a', 14: '#d9ef8b',
    21: '#fee08b', 22: '#fdae61', 26: '#f46d43', 27: '#d73027',
    31: '#762a83', 32: '#9970ab', 33: '#c2a5cf', 34: '#e7d4e8',
    35: '#f7f7f7', 36: '#d9f0d3', 37: '#a6dba0', 38: '#5aae61',
    39: '#00441b', 41: '#006d2c', 42: '#238b45', 43: '#41ab5d',
    44: '#74c476', 45: '#a1d99b', 46: '#c7e9c0', 47: '#e5f5e0',
    48: '#fd8d3c', 49: '#fdae6b', 50: '#fdd0a2', 51: '#fee6ce',
    52: '#e31a1c', 61: '#fb6a4a', 62: '#fc9272'
}

# Create a list of patches for the legend (no numbers in labels)
legend_elements = [Patch(facecolor=koppen_color_map[key], edgecolor='black', label=f"{koppen_labels[key]}") for key in koppen_labels]

# Create the figure and legend
fig, ax = plt.subplots(figsize=(6, 3))  # Adjust the size to fit multiple rows and columns
ax.axis('off')  # Hide axes

# Add the legend to the figure, with multiple columns for compactness
legend = ax.legend(handles=legend_elements, title="Köppen-Geiger Climate Classification", loc='center', ncol=3, frameon=True)

# Save the legend as an image (PNG)
plt.savefig("Koppen_Classification_Legend_Compact.png", bbox_inches='tight', dpi=300)

# Show the plot (optional)
plt.show()

print("Legend image created and saved as 'Koppen_Classification_Legend_Compact.png'")
# Out:
# Legend image created and saved as 'Koppen_Classification_Legend_Compact.png'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Köppen classification labels and colors
koppen_labels = {
    11: 'Af', 12: 'Am', 13: 'As', 14: 'Aw',
    21: 'BWk', 22: 'BWh', 26: 'BSk', 27: 'BSh',
    31: 'Cfa', 32: 'Cfb', 33: 'Cfc', 34: 'Csa',
    35: 'Csb', 36: 'Csc', 37: 'Cwa', 38: 'Cwb',
    39: 'Cwc', 41: 'Dfa', 42: 'Dfb', 43: 'Dfc',
    44: 'Dfd', 45: 'Dsa', 46: 'Dsb', 47: 'Dsc',
    48: 'Dsd', 49: 'Dwa', 50: 'Dwb', 51: 'Dwc',
    52: 'Dwd', 61: 'EF', 62: 'ET'
}

koppen_color_map = {
    11: '#1a9850', 12: '#66bd63', 13: '#a6d96a', 14: '#d9ef8b',
    21: '#fee08b', 22: '#fdae61', 26: '#f46d43', 27: '#d73027',
    31: '#762a83', 32: '#9970ab', 33: '#c2a5cf', 34: '#e7d4e8',
    35: '#f7f7f7', 36: '#d9f0d3', 37: '#a6dba0', 38: '#5aae61',
    39: '#00441b', 41: '#006d2c', 42: '#238b45', 43: '#41ab5d',
    44: '#74c476', 45: '#a1d99b', 46: '#c7e9c0', 47: '#e5f5e0',
    48: '#fd8d3c', 49: '#fdae6b', 50: '#fdd0a2', 51: '#fee6ce',
    52: '#e31a1c', 61: '#fb6a4a', 62: '#fc9272'
}

# Create a list of patches for the legend with 40% opacity (alpha=0.4)
legend_elements = [Patch(facecolor=koppen_color_map[key], edgecolor='black', label=f"{koppen_labels[key]}", alpha=0.4) for key in koppen_labels]

# Create the figure and legend
fig, ax = plt.subplots(figsize=(6, 3))  # Adjust the size to fit multiple rows and columns
ax.axis('off')  # Hide axes

# Add the legend to the figure, with multiple columns for compactness
legend = ax.legend(handles=legend_elements, title="Köppen-Geiger Climate Classification", loc='center', ncol=3, frameon=True)

# Save the legend as an image (PNG)
plt.savefig("Koppen_Classification_Legend_40percent_opacity.png", bbox_inches='tight', dpi=300)

# Show the plot (optional)
plt.show()

print("Legend image created and saved as 'Koppen_Classification_Legend_40percent_opacity.png'")
# Out:
# Legend image created and saved as 'Koppen_Classification_Legend_40percent_opacity.png'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Köppen classification labels, names, and colors for African zones
african_koppen_labels = {
    11: 'Tropical Rainforest (Af)', 
    12: 'Monsoon (Am)', 
    14: 'Savanna (Aw)', 
    21: 'Cold Desert (BWk)', 
    22: 'Hot Desert (BWh)', 
    26: 'Cold Steppe (BSk)', 
    27: 'Hot Steppe (BSh)', 
    31: 'Humid Subtropical (Cfa)', 
    32: 'Oceanic (Cfb)', 
    34: 'Mediterranean, Hot Summer (Csa)', 
    37: 'Subtropical Highland (Cwa)', 
    38: 'Subtropical Highland with Dry Winter (Cwb)',
    62: 'Tundra (ET)'
}

koppen_color_map = {
    11: '#1a9850', 12: '#66bd63', 14: '#d9ef8b',
    21: '#fee08b', 22: '#fdae61', 26: '#f46d43', 27: '#d73027',
    31: '#762a83', 32: '#9970ab', 34: '#e7d4e8', 
    37: '#a6dba0', 38: '#5aae61', 62: '#fc9272'
}

# Create a list of patches for the African legend with 40% opacity
legend_elements = [Patch(facecolor=koppen_color_map[key], edgecolor='black', label=african_koppen_labels[key], alpha=0.4) for key in african_koppen_labels]

# Create the figure and legend
fig, ax = plt.subplots(figsize=(6, 3))  # Adjust size as needed
ax.axis('off')  # Hide axes

# Add the legend to the figure, with multiple columns for compactness
legend = ax.legend(handles=legend_elements, title="Köppen-Geiger Climate Zones (Africa)", loc='center', ncol=2, frameon=True)

# Save the legend as an image (PNG)
plt.savefig("Koppen_Classification_Africa_Legend_40percent_opacity.png", bbox_inches='tight', dpi=300)

# Show the plot (optional)
plt.show()

print("Legend image created and saved as 'Koppen_Classification_Africa_Legend_40percent_opacity.png'")
# Out:
# Legend image created and saved as 'Koppen_Classification_Africa_Legend_40percent_opacity.png'
