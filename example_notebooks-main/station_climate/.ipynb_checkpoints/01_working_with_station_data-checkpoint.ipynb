# %% [markdown]
# # Station Data
#
# We now have two datasets containing station based climate observations.
#
#  1) Africa Wide GHCN daily climate observations - https://www.ncei.noaa.gov/products/land-based-station/global-historical-climatology-network-daily
#  2) Johannesburg SAAQIS stations - https://saaqis.environment.gov.za
#
# *(The data is stored in a somewhat strange way but I like the work flow. Please do send opinions on this my way - Peter)*

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
from pathlib import Path
import xarray as xr

# %% [markdown]
# ## GHCN
#
# The Global Historical Climatology Network daily (GHCNd) is an integrated database of daily climate summaries from land surface stations across the globe. GHCNd is made up of daily climate records from numerous sources that have been integrated and subjected to a common suite of quality assurance reviews.

# %%
metadata_gdf = gpd.read_file( "/terra/projects/heat_center/data/climate/observed/GHCN/GHCN_sub_saharan_metadata.geojson")
metadata_gdf
# Out:
#        station_id dtype  start_year  end_year                    geometry
# 0     AGM00060690  TMAX        1992      2024    POINT (5.76700 19.56700)
# 1     AGM00060690  TMIN        1992      2024    POINT (5.76700 19.56700)
# 2     AGM00060690  PRCP        1992      2024    POINT (5.76700 19.56700)
# 3     AGM00060690  TAVG        1992      2024    POINT (5.76700 19.56700)
# 4     AO000066160  TMAX        1963      2021   POINT (13.23300 -8.85000)
# ...           ...   ...         ...       ...                         ...
# 4274  ZI000067983  PRCP        1951      2024  POINT (32.61600 -20.20000)
# 4275  ZI000067983  TAVG        1962      2024  POINT (32.61600 -20.20000)
# 4276  ZI000067991  TMAX        1951      1990  POINT (30.00000 -22.21700)
# 4277  ZI000067991  TMIN        1951      1990  POINT (30.00000 -22.21700)
# 4278  ZI000067991  PRCP        1951      1990  POINT (30.00000 -22.21700)
#
# [4279 rows x 5 columns]

# %%
ds_station = xr.open_zarr('/terra/projects/heat_center/data/climate/observed/GHCN/ghcnd_archive.zarr')
ds_station
# Out:
# <xarray.Dataset> Size: 307MB
# Dimensions:  (ghcn_id: 282, time: 45348)
# Coordinates:
#   * ghcn_id  (ghcn_id) <U11 12kB 'AGM00060690' 'AO000066160' ... 'ZI000067983'
#   * time     (time) datetime64[ns] 363kB 1900-01-01 1900-01-02 ... 2024-02-27
# Data variables:
#     precp    (ghcn_id, time) float64 102MB dask.array<chunksize=(1, 2400), meta=np.ndarray>
#     tmax     (ghcn_id, time) float64 102MB dask.array<chunksize=(1, 2400), meta=np.ndarray>
#     tmin     (ghcn_id, time) float64 102MB dask.array<chunksize=(1, 2400), meta=np.ndarray>

# %% [markdown]
# If we want to select a single station closest to a given point

# %%
from geopy.distance import great_circle

target_lat, target_lon = -26.134734, 28.238075 # OR Tambo International Airport 
target_point = Point(target_lon, target_lat)

# Calculate distances using the Haversine formula
metadata_gdf['Distance'] = metadata_gdf.apply(lambda row: great_circle((row['geometry'].y, row['geometry'].x), (target_lat, target_lon)).kilometers, axis=1)
closest_point = metadata_gdf.loc[metadata_gdf['Distance'].idxmin()]
closest_point
# Out:
# station_id               SFM00068368
# dtype                           TMAX
# start_year                      1974
# end_year                        2020
# geometry      POINT (28.246 -26.139)
# Distance                    0.922428
# Name: 3384, dtype: object

# %% [markdown]
# Only 1 km away

# %%
ds_station.sel(ghcn_id = closest_point.station_id).tmax.plot()

# %% [markdown]
# Let's plot the locations of these stations

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

for idx, row in metadata_gdf.iterrows():
    ax.plot(row.geometry.x, row.geometry.y, marker='x', color='red', markersize=2, transform=ccrs.PlateCarree())

ax.coastlines()
plt.show()

# %% [markdown]
# less good when considering those with a recent 20 year time span

# %%
subset = metadata_gdf[metadata_gdf.start_year < 2000]
subset = subset[subset.end_year > 2020]

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

for idx, row in subset.iterrows():
    ax.plot(row.geometry.x, row.geometry.y, marker='x', color='red', markersize=2, transform=ccrs.PlateCarree())

ax.coastlines()
plt.show()

# %% [markdown]
# # SAAQIS
#
# Hourly station data from a variety of sources - scraped from a web portal.

# %% [markdown]
# The data is split into two files. Metadata in a geojson file and data in a zarr file.

# %%
metadata_gdf = gpd.read_file( "/terra/projects/heat_center/data/climate/observed/SAAQIS_2/SAAQIS_JHB_metadata.geojson")
metadata_gdf
# Out:
#    station_id              name   latitude  longitude  \
# 0          20         Diepkloof -26.250736  27.956447
# 1          23        Kliprivier -26.420222  28.084139
# 2          27          Sebokeng -26.587917  27.841083
# 3          29       Sharpeville -26.689833  27.867889
# 4          31      Three Rivers -26.657017  27.999461
# 5          33           Zamdela -26.845083  27.855778
# 6          35           Etwatwa -26.116611  28.475417
# 7          36         Germiston -26.227361  28.177333
# 8          37          Leondale -26.301917  28.181556
# 9          39           Springs -26.270361  28.416000
# 10         42           Tsakane -26.385442  28.378035
# 11         43         Wattville -26.228056  28.301278
# 12         73         Alexandra -26.106972  28.110556
# 13         79            Jabavu -26.252611  27.872139
# 14         81       Orange Farm -26.479639  27.867111
# 15         93           Balfour -26.662889  28.584750
# ...

# %% [markdown]
# Opening the data in to a geopandas dataframe allows us to subset the stations by geographic extents.
#
# Here's a very random geojson geometry defined using https://geojson.io/

# %%
import geopandas as gpd
import json

# Your GeoJSON string
geojson_string = '''
{
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          [
            [
              28.057412236527313,
              -26.09341220882621
            ],
            [
              27.9679429594284,
              -26.086047452328955
            ],
            [
              27.922527112854567,
              -26.186996322116215
            ],
            [
              27.856991835063184,
              -26.21640412391173
            ],
            [
              27.80029023912479,
              -26.32405477063699
            ],
            [
              27.840507673355802,
              -26.33010036608021
            ],
            [
              27.87928397572344,
              -26.27927967889915
            ],
            [
              28.16095477874103,
              -26.261277594412775
            ],
            [
              28.21899631725094,
              -26.226476370995833
            ],
            [
              28.316643214890803,
              -26.085384460000135
            ],
            [
              28.201984843868274,
              -25.999661620918616
            ],
            [
              28.057412236527313,
              -26.09341220882621
            ]
          ]
        ],
        "type": "Polygon"
      }
    }
  ]
}
'''
geojson_dict = json.loads(geojson_string)
polygon = gpd.GeoDataFrame.from_features(geojson_dict['features'], crs='EPSG:4326')
polygon.plot()
# Out:
# <Axes: >

# %%
metadata_gdf.crs = 'EPSG:4326'
polygon.crs = 'EPSG:4326'


# Perform a spatial join to subset the GeoDataFrame to include only points within the polygon
subset_gdf = gpd.sjoin(metadata_gdf, polygon, how="inner", predicate='within')
subset_gdf
# Out:
#    station_id            name   latitude  longitude  \
# 0          20       Diepkloof -26.250736  27.956447
# 7          36       Germiston -26.227361  28.177333
# 12         73       Alexandra -26.106972  28.110556
# 13         79          Jabavu -26.252611  27.872139
# 29        260  STARCO SPRINGS -26.222100  28.026100
#
#                                          GIS_Monitors                city  \
# 0   [SO2, NO2, NO, NOX, O3, CO, PM2.5, PM10, Black...  Johannesburg Metro
# 7   [SO2, NO2, NO, NOX, CO, PM10, Benzene, Toluen,...    Ekurhuleni Metro
# 12  [SO2, PM2.5, PM10, PM Coarse, WS, WS StdDev, W...  Johannesburg Metro
# 13  [SO2, O3, PM10, WS, WS StdDev, WD, WD StdDev, ...  Johannesburg Metro
# 29  [SO2, NO2, NO, NOX, O3, CO, PM2.5, PM10, PM Co...                 NaN
#
#                       geometry  index_right
# 0   POINT (27.95645 -26.25074)            0
# 7   POINT (28.17733 -26.22736)            0
# 12  POINT (28.11056 -26.10697)            0
# ...

# %% [markdown]
# Open the zarr file contatining data

# %%
ds_station = xr.open_zarr('/terra/projects/heat_center/data/climate/observed/SAAQIS_2/SAAQIS_JHB_subset.zarr')
ds_station
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:          (station_id: 31, time: 166522)
# Coordinates:
#   * station_id       (station_id) <U3 372B '108' '136' '137' ... '81' '93' '94'
#   * time             (time) datetime64[ns] 1MB 2004-12-31T22:00:00 ... 2023-1...
# Data variables: (12/31)
#     1-3 Butadiene    (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Pressure     (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb RelHum       (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Temp         (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb WDirection   (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Wspeed       (station_id, time) float64 41MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     ...               ...
# ...

# %% [markdown]
# subset tosubset_gdf.station_id.to_list()subset_gdf.station_id the stations we are interested in:

# %%
stations = [x for x in subset_gdf.station_id.to_list() if x in list(ds_station.station_id.values)] # some stations in metedata have no data will update metadata soon
ds_station = ds_station.sel(station_id = stations)
ds_station
# Out:
# <xarray.Dataset> Size: 167MB
# Dimensions:          (station_id: 4, time: 166522)
# Coordinates:
#   * station_id       (station_id) <U3 48B '20' '36' '73' '79'
#   * time             (time) datetime64[ns] 1MB 2004-12-31T22:00:00 ... 2023-1...
# Data variables: (12/31)
#     1-3 Butadiene    (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Pressure     (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb RelHum       (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Temp         (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb WDirection   (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     Amb Wspeed       (station_id, time) float64 5MB dask.array<chunksize=(1, 10000), meta=np.ndarray>
#     ...               ...
# ...

# %% [markdown]
# Let's plot it

# %%
x = ds_station['Amb Temp']
x = x.dropna(how = 'all', dim = 'station_id') # where all data is none
x.plot.line(x = 'time')

# %% [markdown]
# Clearly some bad data

# %%
x = ds_station['Amb Temp']#.sel(time = '2023')
x = x.where((x > -30) & (x < 50)) # subset to greater than -30 or less than 50
x = x.dropna(how = 'all', dim = 'station_id') # where all data is none
x.plot.line(x = 'time')

# %% [markdown]
# Better but no correct, cleaning station data is tricky

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

for idx, row in metadata_gdf.iterrows():
    ax.plot(row.geometry.x, row.geometry.y, marker='x', color='red', markersize=2, transform=ccrs.PlateCarree())

ax.coastlines()

ax.set_extent([16, 33, -35, -22], crs=ccrs.PlateCarree())

plt.show()
